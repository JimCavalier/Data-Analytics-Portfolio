# %% [markdown]
# ## Social Media vs Productivity

# %% [markdown]
# #### Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Import .CSV

# %%
data = pd.read_csv('social_media_vs_productivity.csv')

# %% [markdown]
# #### Examine Data

# %%
data.head()
# Out:
#    age  gender    job_type  daily_social_media_time  \
# 0   56    Male  Unemployed                 4.180940
# 1   46    Male      Health                 3.249603
# 2   32    Male     Finance                      NaN
# 3   60  Female  Unemployed                      NaN
# 4   25    Male          IT                      NaN
#
#   social_platform_preference  number_of_notifications  work_hours_per_day  \
# 0                   Facebook                       61            6.753558
# 1                    Twitter                       59            9.169296
# 2                    Twitter                       57            7.910952
# 3                   Facebook                       59            6.355027
# 4                   Telegram                       66            6.214096
#
#    perceived_productivity_score  actual_productivity_score  stress_level  \
# 0                      8.040464                   7.291555           4.0
# ...

# %%
data.shape
# Out:
# (30000, 19)

# %%
data.describe()
# Out:
#                 age  daily_social_media_time  number_of_notifications  \
# count  30000.000000             27235.000000             30000.000000
# mean      41.486867                 3.113418                59.958767
# std       13.835221                 2.074813                 7.723772
# min       18.000000                 0.000000                30.000000
# 25%       30.000000                 1.639566                55.000000
# 50%       41.000000                 3.025913                60.000000
# 75%       53.000000                 4.368917                65.000000
# max       65.000000                17.973256                90.000000
#
#        work_hours_per_day  perceived_productivity_score  \
# count        30000.000000                  28386.000000
# mean             6.990792                      5.510488
# std              1.997736                      2.023470
# min              0.000000                      2.000252
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   age                             30000 non-null  int64
#  1   gender                          30000 non-null  object
#  2   job_type                        30000 non-null  object
#  3   daily_social_media_time         27235 non-null  float64
#  4   social_platform_preference      30000 non-null  object
#  5   number_of_notifications         30000 non-null  int64
#  6   work_hours_per_day              30000 non-null  float64
#  7   perceived_productivity_score    28386 non-null  float64
#  8   actual_productivity_score       27635 non-null  float64
#  9   stress_level                    28096 non-null  float64
#  10  sleep_hours                     27402 non-null  float64
#  11  screen_time_before_sleep        27789 non-null  float64
# ...

# %%
data.isnull().sum()
# Out:
# age                                  0
# gender                               0
# job_type                             0
# daily_social_media_time           2765
# social_platform_preference           0
# number_of_notifications              0
# work_hours_per_day                   0
# perceived_productivity_score      1614
# actual_productivity_score         2365
# stress_level                      1904
# sleep_hours                       2598
# screen_time_before_sleep          2211
# breaks_during_work                   0
# uses_focus_apps                      0
# has_digital_wellbeing_enabled        0
# coffee_consumption_per_day           0
# days_feeling_burnout_per_month       0
# weekly_offline_hours                 0
# job_satisfaction_score            2730
# dtype: int64

# %% [markdown]
# #### Drop Rows with Null values

# %%
dfclean = data.dropna()

# %%
dfclean.isnull().sum()
# Out:
# age                               0
# gender                            0
# job_type                          0
# daily_social_media_time           0
# social_platform_preference        0
# number_of_notifications           0
# work_hours_per_day                0
# perceived_productivity_score      0
# actual_productivity_score         0
# stress_level                      0
# sleep_hours                       0
# screen_time_before_sleep          0
# breaks_during_work                0
# uses_focus_apps                   0
# has_digital_wellbeing_enabled     0
# coffee_consumption_per_day        0
# days_feeling_burnout_per_month    0
# weekly_offline_hours              0
# job_satisfaction_score            0
# dtype: int64

# %%
dfclean.shape
# Out:
# (17074, 19)

# %%
dfclean.describe()
# Out:
#                 age  daily_social_media_time  number_of_notifications  \
# count  17074.000000             17074.000000             17074.000000
# mean      41.462926                 3.122575                59.974288
# std       13.835084                 2.080257                 7.788587
# min       18.000000                 0.000000                32.000000
# 25%       30.000000                 1.647730                55.000000
# 50%       41.000000                 3.036425                60.000000
# 75%       53.000000                 4.367746                65.000000
# max       65.000000                17.817948                90.000000
#
#        work_hours_per_day  perceived_productivity_score  \
# count        17074.000000                  17074.000000
# mean             6.989841                      5.505523
# std              1.995280                      2.026415
# min              0.000000                      2.000252
# ...

# %%
dfclean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17074 entries, 0 to 29998
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   age                             17074 non-null  int64
#  1   gender                          17074 non-null  object
#  2   job_type                        17074 non-null  object
#  3   daily_social_media_time         17074 non-null  float64
#  4   social_platform_preference      17074 non-null  object
#  5   number_of_notifications         17074 non-null  int64
#  6   work_hours_per_day              17074 non-null  float64
#  7   perceived_productivity_score    17074 non-null  float64
#  8   actual_productivity_score       17074 non-null  float64
#  9   stress_level                    17074 non-null  float64
#  10  sleep_hours                     17074 non-null  float64
#  11  screen_time_before_sleep        17074 non-null  float64
# ...

# %%
dfclean.describe()

# %% [markdown]
# #### Scatter plot- media time v percieved production

# %%
x= df['daily_social_media_time'].values
y= df['actual_productivity_score'].values
plt.scatter(x,y)
plt.xlabel('Media Time')
plt.ylabel('Productivity')
#plt.legend()
#plt.show()

# %% [markdown]
# #### Heatmap

# %%
#create frame for heatmap
hm=dfclean

#drop columns
hm = hm.drop(columns=['stress_level', 'sleep_hours', 'screen_time_before_sleep', 'work_hours_per_day','age',
                      'breaks_during_work','coffee_consumption_per_day', 'weekly_offline_hours', 'days_feeling_burnout_per_month'  ])

# Compute correlation matrix
co_mtx = hm.corr(numeric_only=True)

# Print correlation matrix
#print(co_mtx)

# Plot correlation heatmap
sns.heatmap(co_mtx, cmap="YlGnBu", annot=True)

# Display heatmap
plt.show()

# %%
columns = ['daily_social_media_time', 'number_of_notifications', 'perceived_productivity_score', 'actual_productivity_score',
          'uses_focus_apps', 'has_digital_wellbeing_enabled', 'job_satisfaction_score']
data[columns].corr()
# Out:
#                                daily_social_media_time  \
# daily_social_media_time                       1.000000
# number_of_notifications                      -0.000915
# perceived_productivity_score                 -0.011224
# actual_productivity_score                    -0.010924
# uses_focus_apps                              -0.004950
# has_digital_wellbeing_enabled                -0.003776
# job_satisfaction_score                       -0.004357
#
#                                number_of_notifications  \
# daily_social_media_time                      -0.000915
# number_of_notifications                       1.000000
# perceived_productivity_score                 -0.003873
# actual_productivity_score                     0.000457
# uses_focus_apps                               0.004320
# has_digital_wellbeing_enabled                -0.001722
# job_satisfaction_score                       -0.004716
#
#                                perceived_productivity_score  \
# ...

# %%
data[columns].corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d570b_row0_col0, #T_d570b_row1_col1, #T_d570b_row2_col2, #T_d570b_row3_col3, #T_d570b_row4_col4, #T_d570b_row5_col5, #T_d570b_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d570b_row0_col1, #T_d570b_row0_col2, #T_d570b_row0_col3, #T_d570b_row0_col4, #T_d570b_row0_col5, #T_d570b_row0_col6, #T_d570b_row1_col6, #T_d570b_row2_col0, #T_d570b_row2_col1, #T_d570b_row2_col4, #T_d570b_row2_col5, #T_d570b_row3_col0, #T_d570b_row3_col5, #T_d570b_row5_col1, #T_d570b_row5_col6, #T_d570b_row6_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d570b_row1_col0, #T_d570b_row1_col3, #T_d570b_row1_col4, #T_d570b_row4_col1, #T_d570b_row4_col3, #T_d570b_row4_col5, #T_d570b_row4_col6, #T_d570b_row5_col4, #T_d570b_row6_col4 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# ...

# %%
columns = ['job_satisfaction_score', 'work_hours_per_day', 'weekly_offline_hours', 'daily_social_media_time',
           'breaks_during_work','stress_level', 'actual_productivity_score']
data[columns].corr()
# Out:
#                            job_satisfaction_score  work_hours_per_day  \
# job_satisfaction_score                   1.000000           -0.002155
# work_hours_per_day                      -0.002155            1.000000
# weekly_offline_hours                    -0.005723           -0.002061
# daily_social_media_time                 -0.004357           -0.003049
# breaks_during_work                      -0.003262           -0.008151
# stress_level                            -0.000569            0.002348
# actual_productivity_score                0.882965           -0.000113
#
#                            weekly_offline_hours  daily_social_media_time  \
# job_satisfaction_score                -0.005723                -0.004357
# work_hours_per_day                    -0.002061                -0.003049
# weekly_offline_hours                   1.000000                -0.001555
# daily_social_media_time               -0.001555                 1.000000
# ...

# %%
data[columns].corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b5d9b_row0_col0, #T_b5d9b_row1_col1, #T_b5d9b_row2_col2, #T_b5d9b_row3_col3, #T_b5d9b_row4_col4, #T_b5d9b_row5_col5, #T_b5d9b_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b5d9b_row0_col1, #T_b5d9b_row0_col3, #T_b5d9b_row0_col4, #T_b5d9b_row1_col3, #T_b5d9b_row1_col5, #T_b5d9b_row2_col1, #T_b5d9b_row2_col6, #T_b5d9b_row3_col1, #T_b5d9b_row3_col2, #T_b5d9b_row3_col5, #T_b5d9b_row4_col5, #T_b5d9b_row4_col6, #T_b5d9b_row5_col0, #T_b5d9b_row6_col4, #T_b5d9b_row6_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_b5d9b_row0_col2, #T_b5d9b_row0_col5, #T_b5d9b_row1_col0, #T_b5d9b_row1_col2, #T_b5d9b_row1_col4, #T_b5d9b_row2_col0, #T_b5d9b_row2_col5, #T_b5d9b_row3_col0, #T_b5d9b_row3_col6, #T_b5d9b_row4_col0, #T_b5d9b_row4_col1, #T_b5d9b_row5_col2, #T_b5d9b_row6_col2, #T_b5d9b_row6_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b5d9b_row0_col6, #T_b5d9b_row6_col0 {
#   background-color: #da5a49;
# ...
